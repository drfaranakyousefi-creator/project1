# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/nimashomalii/split_learning.git
# %cd split_learning
from TrainTest import HTTPS
import plot
w , dataset_name,batch_size = 3 , 'metavision' , 128
server_url = "https://701c61029189.ngrok-free.app/prediction"
https_client = HTTPS(w , dataset_name,batch_size , server_url)
history = https_client.fit(5)
plot.plot_history(history)
# Out:
# Cloning into 'split_learning'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 56 (delta 22), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (56/56), 72.35 KiB | 2.41 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /content/split_learning
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1565295624.py in <cell line: 0>()
#       5 w , dataset_name,batch_size = 3 , 'metavision' , 128
#       6 server_url = "https://701c61029189.ngrok-free.app/prediction"
# ----> 7 https_client = HTTPS(w , dataset_name,batch_size , server_url)
#       8 history = https_client.fit(5)
#       9 plot.plot_history(history)
#
# /content/split_learning/TrainTest.py in __init__(self, w, dataset_name, batch_size, server_url)
#      16         else:
# ...
